# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams['font.sans-serif']='SimHei'
plt.rcParams['axes.unicode_minus']=False

# %%
#读取员工离职预测数据
df = pd.read_csv(r"C:\Users\zhouy\Desktop\数据科学技术与应用\员工离职预测训练赛\pfm_train.csv",delimiter=',')

# %%
#数据降维：剔除无关变量“EmployeeNumber”(员工号码)、“Over18”（年龄是否超过18）、“StandardHours”（标准工时）
df = df.drop(['EmployeeNumber','Over18','StandardHours'],axis=1)

# %%
fig=plt.figure(figsize=(10,4))
#查看TotalWorkingYears与离职的关系
ax1 = fig.add_subplot(1,2,1)
data1 = df[['TotalWorkingYears','Attrition']]   
data1.plot(kind='box', by='Attrition',grid=False,notch=True,figsize=(4,4),sym='.',ax=ax1)
plt.title('员工总工作年数与离职的关系')
plt.xticks([1,2],['在职','离职'])

#查看MonthlyIncome与离职的关系
ax2 = fig.add_subplot(1,2,2)
data2 = df[['MonthlyIncome','Attrition']]   
data2.plot(kind='box',by='Attrition',grid=False,notch=True,sym='.',ax=ax2)
plt.title('员工月工资与离职的关系')
plt.xticks([1,2],['在职','离职'])
plt.show()

# %%
fig=plt.figure(figsize=(10,4))
#查看JobLevel与离职的关系
ax1 = fig.add_subplot(1,2,1)
data1 = df[['JobLevel','Attrition']]   
data1.plot(kind='box', by='Attrition',grid=False,notch=False,figsize=(4,4),sym='.',ax=ax1)
plt.title('员工职业级别与离职的关系')
plt.xticks([1,2],['在职','离职'])

#查看Age与离职的关系
ax2 = fig.add_subplot(1,2,2)
data2 = df[['Age','Attrition']]   
data2.plot(kind='box',by='Attrition',grid=False,sym='.',notch=True,ax=ax2)
plt.title('员工年龄与离职的关系')
plt.xticks([1,2],['在职','离职'])
plt.show()

# %%
fig=plt.figure(figsize=(10,4))
#查看YearsAtCompany与离职的关系
ax1 = fig.add_subplot(1,2,1)
data1 = df[['YearsAtCompany','Attrition']]   
data1.plot(kind='box', by='Attrition',grid=False,notch=True,figsize=(4,4),sym='.',ax=ax1)
plt.title('员工在目前公司工作年数与离职的关系')
plt.xticks([1,2],['在职','离职'])

#查看YearsInCurrentRole与离职的关系
ax2 = fig.add_subplot(1,2,2)
data2 = df[['YearsInCurrentRole','Attrition']]   
data2.plot(kind='box',by='Attrition',grid=False,notch=True,sym='.',ax=ax2)
plt.title('员工在目前岗位工作年数与离职的关系')
plt.xticks([1,2],['在职','离职'])
plt.show()

# %%
fig=plt.figure(figsize=(10,4))
#查看StockOptionLevel与离职的关系
ax1 = fig.add_subplot(1,2,1)
data1 = df[['StockOptionLevel','Attrition']]   
data1.plot(kind='box', by='Attrition',grid=False,notch=False,figsize=(4,4),sym='.',ax=ax1)
plt.title('员工股票期权水平与离职的关系')
plt.xticks([1,2],['在职','离职'])

#查看YearsWithCurrManager与离职的关系
ax2 = fig.add_subplot(1,2,2)
data2 = df[['YearsWithCurrManager','Attrition']]   
data2.plot(kind='box',by='Attrition',grid=False,notch=True,sym='.',ax=ax2)
plt.title('员工与目前管理者共事年数与离职的关系')
plt.xticks([1,2],['在职','离职'])
plt.show()

# %%
fig=plt.figure(figsize=(10,4))
#查看JobSatisfaction与离职的关系
ax1 = fig.add_subplot(1,2,1)
data1 = df[['JobSatisfaction','Attrition']]   
data1.plot(kind='box', by='Attrition',grid=False,notch=False,figsize=(4,4),sym='.',ax=ax1)
plt.title('员工工作满意度与离职的关系')
plt.xticks([1,2],['在职','离职'])

#查看JobInvolvement与离职的关系
ax2 = fig.add_subplot(1,2,2)
data2 = df[['JobInvolvement','Attrition']]   
data2.plot(kind='box',by='Attrition',grid=False,notch=False,medianprops={'linewidth':1.5,'color':'green'},ax=ax2)
plt.title('员工工作投入度与离职的关系')
plt.xticks([1,2],['在职','离职'])
plt.show()
